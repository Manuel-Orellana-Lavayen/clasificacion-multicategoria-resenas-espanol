# %%
# %load_ext watermark
# %watermark -a "Manuel Elias Orellana Lavayen" -d -v -iv
# Out:
# Author: Manuel Elias Orellana Lavayen
#
# Date: 2026-08-29
#
# Python implementation: CPython
# Python version       : 3.12.10
# IPython version      : 9.17.0

# %%
from pathlib import Path
ruta_base = Path.cwd() #Ruta base

# %%
import spacy

nlp = spacy.load("es_core_news_md")

ruta_destino = ruta_base /"Recursos de procesamiento de texto/es_core_news_md"

nlp.to_disk(ruta_destino)

# %%
from sentence_transformers import SentenceTransformer
modelo = SentenceTransformer("intfloat/multilingual-e5-base")
ruta = ruta_base / "Recursos de procesamiento de texto/multilingual-e5-base"
modelo.save(path= str(ruta))
# Out:
# ...
# Writing model shards:   0%|          | 0/1 [00:00<?, ?it/s]
